# %%
import pandas as pd
import seaborn as sns
import os
from openai import OpenAI
import configurations as c

# %%
df = pd.read_csv("data/DisneylandReviews.csv", encoding='latin1')
df['Branch'] = df['Branch'].astype('category')
df["Year_Month"] = pd.to_datetime(df["Year_Month"], format="%Y-%m", errors = "coerce")
df["Reviewer_Location"] = df["Reviewer_Location"].astype('category')
df = df.rename(columns={
    "Reviewer_Location" : "Location"
})

# %%
#make a new dataset randomly sampling 1000 entries
df_sample = df.sample(n=1000, random_state=1)
df_sample
# Out:
#        Review_ID  Rating Year_Month        Location  \
# 12008  531138321       5 2017-09-01  United Kingdom
# 42394   25004598       1        NaT   United States
# 24748  155279085       5 2012-12-01   United States
# 42609    3460644       1        NaT   United States
# 10719  594693531       5 2018-07-01   United States
# ...          ...     ...        ...             ...
# 18743  283963913       5 2015-06-01   United States
# 34250  362480264       4 2016-04-01  United Kingdom
# 34894  330029779       5 2015-11-01     New Zealand
# 38297  204781099       4 2014-05-01  United Kingdom
# 1339   558932183       4 2017-07-01           India
#
#                                              Review_Text  \
# 12008  We visited for Mickey;s Not So Scary Halloween...
# 42394  We arrived on 15th February 2009 and were due ...
# 24748  Nothing really new in the Magic Kingdom from t...
# 42609  My husband and I recently returned from a long...
# 10719  You will definitely want to plan out your day,...
# ...                                                  ...
# 18743  The park was awesome and all of the 60th decor...
# 34250  What more can I say my 2 kids 4 and 6 had an a...
# 34894  Cannot fault the visit. The magic totally aliv...
# 38297  We Went to disneyland from Friday 2nd Monday 5...
# 1339   Well   . visiting Disney Land for the first ti...
#
#                       Branch
# 12008  Disneyland_California
# 42394       Disneyland_Paris
# 24748  Disneyland_California
# 42609       Disneyland_Paris
# 10719  Disneyland_California
# ...                      ...
# 18743  Disneyland_California
# 34250       Disneyland_Paris
# 34894       Disneyland_Paris
# 38297       Disneyland_Paris
# 1339     Disneyland_HongKong
#
# [1000 rows x 6 columns]

# %%
from pydantic import BaseModel
from typing import List, Optional

class CodedElement(BaseModel):
    touchpoint: str
    sentiment: str # "positive" or "negative"
    code: str
    text_excerpt: str

class DemographicInfo(BaseModel):
    travel_party: Optional[str] = None
    first_visit: Optional[str] = None # "Yes", "No", or "Unknown"
    visit_timing: Optional[str] = None # Season, holiday, time of day, day of week

class ReviewAnalysis(BaseModel):
    review_id: str
    coded_elements: List[CodedElement]
    demographic_info: DemographicInfo

# %%
def prompt():
    """
    You are tasked with analyzing Disneyland reviews to identify the primary drivers of guest satisfaction across the complete guest journey.

    For each review, identify specific mentions that affected the guest experience at different touchpoints, marking them as either positive or negative.

    GUEST JOURNEY TOUCHPOINTS:
    Use ONLY the following touchpoint categories (do not create your own) - all in lowercase:
    - pre-visit (use for planning, booking, website experience, app usage before arrival)
    - entry/admission (use for parking, tickets, entry gates, security screening, arrival experience)
    - attractions (use for rides, interactive exhibits, wait times, ride operations)
    - entertainment (use for parades, shows, fireworks, street performers)
    - characters (use for character meet-and-greets, character interactions, photo opportunities)
    - staff (use for all employee interactions including ride operators, food service staff, retail staff)
    - food/beverage (use for restaurants, snack stands, food quality, dining experience)
    - retail (use for shopping experiences, merchandise, souvenirs)
    - facilities (use for restrooms, baby care, first aid, accessibility features)
    - cleanliness (use for park maintenance, trash management, overall park cleanliness)
    - navigation (use for park layout, wayfinding, walking experience, crowding)
    - value (use for price-related comments, perceived worth, packages, discounts)
    - atmosphere (use for theming, ambiance, music, decorations, overall feel)
    - timing (use ONLY when time of visit directly impacts satisfaction, such as "weekday visits are better" or "morning hours have shorter lines")
    - post-visit (use for follow-up, memories, overall reflections after leaving)
    - comparison (use when comparing to other Disney parks or similar attractions)

    DEMOGRAPHIC INFO:
    For demographic information, capture the following when mentioned (even if just mentioned factually without impact on satisfaction):
    - Travel party composition (family, couple, solo, friends)
    - First visit status (yes/no)
    - Visit timing (season, holiday, time of day, day of week)

    QUEUE-RELATED CODING GUIDELINES:
    For any mention of queues, waiting times, lines, or crowding across ANY touchpoint:
    1. Always include one of these terms in your code: "queue", "wait time", "line", or "crowding"
    2. Be specific about which service the queue is for (e.g., "short ride queues" rather than just "short queues")
    3. Place the queue code under the most relevant touchpoint:
       - attractions: for ride queues, virtual queues, FastPass systems
       - entry/admission: for entry gates, ticket booths, security screening
       - food/beverage: for restaurant waiting, ordering lines, pickup queues
       - entertainment: for show seating, parade viewing spots
       - characters: for character meet-and-greet lines
       - facilities: for restroom queues
       - navigation: for general crowding or movement flow issues

    CODES:
    Your codes must identify the specific driver of satisfaction or dissatisfaction, capturing the exact aspect that influenced the experience.
    Examples of good codes:
    - "efficient online ticket purchase" (pre-visit)
    - "short security line wait" (entry/admission)
    - "minimal ride queue times" (attractions)
    - "convenient virtual queue system" (attractions)
    - "manageable character line wait" (characters)
    - "knowledgeable staff recommendations" (staff)
    - "quick food service lines" (food/beverage)
    - "reasonable restroom wait times" (facilities)
    - "excessive parade viewing crowding" (entertainment)
    - "low general crowd density" (navigation)
    - "advantageous weekday crowds" (timing)

    IMPORTANT DISTINCTION:
    - Only code "timing" as a touchpoint when it DIRECTLY impacts satisfaction (e.g., "Going on weekdays was great because there were no lines!")
    - When timing is just mentioned factually without directly affecting satisfaction (e.g., "We visited in December"), capture it in demographic_info.visit_timing

    For each coded element, provide:
    - The specific touchpoint category (from the list above, in lowercase)
    - Sentiment as "positive" or "negative" (not "+" or "-")
    - A specific descriptive code (3-5 words that precisely identify the satisfaction driver)
    - The exact text excerpt from the review that supports this code (do not alter the quote)

    Structure your output according to the provided schema.
    Here is the review:
    """
    return prompt.__doc__

# %%
#if u want to use gemini
from google import genai

secret = c.GEMINI_API_KEY
client = genai.Client(api_key = secret)
def chatgpt(input):
    response = client.models.generate_content(
        model='gemini-2.0-flash',
        contents=input,
        config={
            'response_mime_type': 'application/json',
            'response_schema': ReviewAnalysis,
            'system_instruction': prompt() 
        },
    )
    return response.text

# %%
#if you want to use chatgpt
secret = c.OPENAI_API_KEY
client = OpenAI(api_key = secret)
def chatgpt(input_text: str) -> ReviewAnalysis:
    system_prompt = prompt()
    user_prompt = input_text 
    response = client.beta.chat.completions.parse(
        model="gpt-4o-mini-2024-07-18",
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt},
        ],
        response_format = ReviewAnalysis
    )
    return response.choices[0].message

# %%
# function to analyze the dataframe of reviews
llm_output = []
for i in range(800, 1000):
    review = input = f"ID: {df_sample.iloc[i]['Review_ID']}, Review Text:{df_sample.iloc[i]["Review_Text"]}, Where the reviewer is from: {df_sample.iloc[i]['Location']}, Disney Branch: {df_sample.iloc[i]['Branch']}"
    response = chatgpt(review)
    print(response)
    print(f"{i}TH REVIEW")
    llm_output.append(response)
# Out:
# {
#   "review_id": "74875940",
#   "coded_elements": [
#     {
#       "touchpoint": "value",
#       "sentiment": "negative",
#       "code": "expensive overall experience",
#       "text_excerpt": "It was so expensive"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "excessive ride queue times",
#       "text_excerpt": "the lines are too long."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "long ride wait time",
#       "text_excerpt": "The wiat time for a ride that was like 1 minute long, was at least 70 minutes"
#     },
#     {
#       "touchpoint": "value",
#       "sentiment": "negative",
#       "code": "questionable cost worth",
#       "text_excerpt": "Was it worth the cost? I doubt it."
#     },
#     {
#       "touchpoint": "staff",
#       "sentiment": "positive",
#       "code": "staff trying their best",
#       "text_excerpt": "The staff try their best I guess."
#     },
#     {
#       "touchpoint": "value",
#       "sentiment": "positive",
#       "code": "santa fe hotel better value",
#       "text_excerpt": "If u want value for money try Hotel Santa Fe"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "check-in crowding",
#       "text_excerpt": "The number of people at the check in"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "bus crowding",
#       "text_excerpt": "at the bus"
#     },
#     {
#       "touchpoint": "timing",
#       "sentiment": "negative",
#       "code": "summer visit overcrowding",
#       "text_excerpt": "Durign the summer, the lines are too long."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": null,
#     "visit_timing": "summer"
#   }
# }
# 800TH REVIEW
# {
#   "review_id": "612790407",
#   "coded_elements": [
#     {
#       "touchpoint": "characters",
#       "sentiment": "positive",
#       "code": "enjoyable character meet and greets",
#       "text_excerpt": "The character meet and greets were a good touch"
#     },
#     {
#       "touchpoint": "characters",
#       "sentiment": "negative",
#       "code": "long character meet queues",
#       "text_excerpt": "even if they queues were quite long"
#     },
#     {
#       "touchpoint": "comparison",
#       "sentiment": "negative",
#       "code": "inferior to USA Disney",
#       "text_excerpt": "it s not fair comparing it to USA Disney but it falls so far short it s incredible"
#     },
#     {
#       "touchpoint": "pre-visit",
#       "sentiment": "negative",
#       "code": "unusable app for booking",
#       "text_excerpt": "We came for meet and greet with Captain America which relies on an App to book....it is impossible to book anything on the app."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "feature attraction unattainable",
#       "text_excerpt": "So basically, the feature attraction is unattainable."
#     },
#     {
#       "touchpoint": "staff",
#       "sentiment": "negative",
#       "code": "unhelpful customer service",
#       "text_excerpt": "Complaints about this are dismissed by customer service staff out of hand."
#     },
#     {
#       "touchpoint": "staff",
#       "sentiment": "negative",
#       "code": "subpar disney employee standards",
#       "text_excerpt": "In general staff are not Disney standard very little is done to answer questions or deal with issues and there is certainly no evidence of going above and beyond"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "poor fastpass availability",
#       "text_excerpt": "availability of Fast Pass is poor"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "inefficient fastpass implementation",
#       "text_excerpt": "It is employed on some attraction when not needed and is missing on others where it would be useful"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "negative",
#       "code": "falls below disney expectations",
#       "text_excerpt": "Falls well below what I perceive the Disney experience to be"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": "4 days"
#   }
# }
# 801TH REVIEW
# {
#   "review_id": "284004313",
#   "coded_elements": [
#     {
#       "touchpoint": "pre-visit",
#       "sentiment": "positive",
#       "code": "learning about fast passes",
#       "text_excerpt": "Learning how to use the fast passes is key. Take the time to read up about it on line."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "rode all wanted rides",
#       "text_excerpt": "We rode all the rides we wanted and them some."
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "harder finding healthy food",
#       "text_excerpt": "I found it harder to find healthy food then at California Adventure"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "delicious baked potatoes found",
#       "text_excerpt": "but finally found baked potato's at a little place just past the Haunted Mansion. And they were delicious!"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 802TH REVIEW
# {
#   "review_id": "315723484",
#   "coded_elements": [
#     {
#       "touchpoint": "staff",
#       "sentiment": "positive",
#       "code": "friendly and helpful staff",
#       "text_excerpt": "Staff were very friendly and helpful"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "acceptable ride wait time",
#       "text_excerpt": "Wait for rides was acceptable"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "great fast pass bonus",
#       "text_excerpt": "the fast pass was a great bonus"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 803TH REVIEW
# {
#   "review_id": "187519300",
#   "coded_elements": [
#     {
#       "touchpoint": "pre-visit",
#       "sentiment": "negative",
#       "code": "incorrect restaurant price quote",
#       "text_excerpt": "I had asked if it was All You Can Eat as I could recall from my last visit years ago, and she replied, Yes, Its $10 per person."
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "unexpectedly high buffet price",
#       "text_excerpt": "the waitress had informed us that the food was $24.99 per person"
#     },
#     {
#       "touchpoint": "staff",
#       "sentiment": "positive",
#       "code": "sympathetic waitress apologized",
#       "text_excerpt": "The waitress was wonderful and expressed her apologies for the misunderstanding and had tried to see what she could do for us."
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "no visible menu prices",
#       "text_excerpt": "There was no menu to display the buffet fee, and nobody had bothered to explain it as we entered the Thunder Barbecue Ranch."
#     },
#     {
#       "touchpoint": "staff",
#       "sentiment": "negative",
#       "code": "unhelpful city hall staff",
#       "text_excerpt": "He was a very ignorant and arrogant worker who had no intention of helping from the very beginning."
#     },
#     {
#       "touchpoint": "staff",
#       "sentiment": "negative",
#       "code": "staff lied about recording",
#       "text_excerpt": "We went back and had asked him to listen to the recording, he said  We don't record our phone calls.  and I called him out on telling us that he was going to listen to the recording."
#     },
#     {
#       "touchpoint": "staff",
#       "sentiment": "negative",
#       "code": "staff disregarded budget concerns",
#       "text_excerpt": "Yes she told me that but I didn't think I should bring it up."
#     },
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "negative",
#       "code": "ruined trip and disappointment",
#       "text_excerpt": "After this, my boyfriend and myself found ourselves broke. We had barely enough to pay for the dinner and our day was ruined."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "couple",
#     "first_visit": "no",
#     "visit_timing": "Christmas time"
#   }
# }
# 804TH REVIEW
# {
#   "review_id": "490434614",
#   "coded_elements": [
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "positive",
#       "code": "enjoyed park thoroughly",
#       "text_excerpt": "we enjoyed it thoroughly"
#     },
#     {
#       "touchpoint": "timing",
#       "sentiment": "positive",
#       "code": "extended hours unhurried experience",
#       "text_excerpt": "park was open until 11 at night which meant we could take our time to enjoy the attractions and not feel rushed"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "pretty anniversary colours",
#       "text_excerpt": "The colours on display for the 25th anniversary celebrations were so pretty"
#     },
#     {
#       "touchpoint": "timing",
#       "sentiment": "positive",
#       "code": "quiet park enjoyed thoroughly",
#       "text_excerpt": "park was so quiet"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "short ride queue time",
#       "text_excerpt": "Longest wait was for big thunder mountain and that was only half an hour."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "walk on rides",
#       "text_excerpt": "Walked on to star tours, phantom manor, buzz etc."
#     },
#     {
#       "touchpoint": "timing",
#       "sentiment": "positive",
#       "code": "recommend visit time",
#       "text_excerpt": "Would definitely recommend this time of year."
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "lovely weather",
#       "text_excerpt": "Weather was lovely too."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": "no",
#     "visit_timing": "last day of may"
#   }
# }
# 805TH REVIEW
# {
#   "review_id": "384687729",
#   "coded_elements": [
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "fabulous parade experience",
#       "text_excerpt": "The Paint the Night parade was fabulous!!!"
#     },
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "positive",
#       "code": "memorable family vacation",
#       "text_excerpt": "Truly a must vacation with your family! We were able to see and do so much!"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 806TH REVIEW
# {
#   "review_id": "123383607",
#   "coded_elements": [
#     {
#       "touchpoint": "characters",
#       "sentiment": "positive",
#       "code": "princesses come to table",
#       "text_excerpt": "took my girls to have breakfast with the princesses which is a great way to have the princesses coming to your table instead of hours trying to find them for a picture"
#     },
#     {
#       "touchpoint": "characters",
#       "sentiment": "negative",
#       "code": "avoid hours searching princesses",
#       "text_excerpt": "instead of hours trying to find them for a picture"
#     },
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "positive",
#       "code": "always a great place",
#       "text_excerpt": "Disneyland is always a great place to go!!"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": null,
#     "visit_timing": "birthday"
#   }
# }
# 807TH REVIEW
# {
#   "review_id": "129277603",
#   "coded_elements": [
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "positive",
#       "code": "fun first Disneyland experience",
#       "text_excerpt": "it was definately a fun day for me"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "positive",
#       "code": "compact park layout",
#       "text_excerpt": "everything is compact and closer to each other so each attractions are closer, meaning less walk and we are able to cover the whole park within a day"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "negative",
#       "code": "unable to understand characters",
#       "text_excerpt": "everything was in cantonese and i couldn't understand what the characters are talking about which is not fun"
#     },
#     {
#       "touchpoint": "characters",
#       "sentiment": "negative",
#       "code": "queue cutting tourists",
#       "text_excerpt": "there are always flocks of mainland tourists around, meaning if you are not aware, they will cut the queue"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "tourists bumping into people",
#       "text_excerpt": "flocks of mainland tourists around...they will...bump into you"
#     },
#     {
#       "touchpoint": "comparison",
#       "sentiment": "positive",
#       "code": "prefers compact HK Disneyland",
#       "text_excerpt": "I really enjoyed disneyland in HK... everything is compact and closer to each other"
#     },
#     {
#       "touchpoint": "comparison",
#       "sentiment": "negative",
#       "code": "LA Disneyland too big",
#       "text_excerpt": "it is just too big for a 1 day trip"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": "yes",
#     "visit_timing": null
#   }
# }
# 808TH REVIEW
# {
#   "review_id": "176139579",
#   "coded_elements": [
#     {
#       "touchpoint": "pre-visit",
#       "sentiment": "negative",
#       "code": "lack of attraction notice",
#       "text_excerpt": "they should mention this on their website or at least give a discount if they would be honest"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "major attractions unavailable",
#       "text_excerpt": "two of the major attractions were off that week"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "fastpass system malfunction",
#       "text_excerpt": "We took a fastpass for the splash mountain but it wasn't working when we arrived."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "ride broke down",
#       "text_excerpt": "But while being in the attraction, it broke down and they had to evacuate us."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "long fastpass queue wait",
#       "text_excerpt": "the fast pass lines elsewhere became long as well (min. 30 min of waiting)"
#     },
#     {
#       "touchpoint": "value",
#       "sentiment": "negative",
#       "code": "waste of money",
#       "text_excerpt": "So for me, it was a big waste of money"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "huge park crowding",
#       "text_excerpt": "The crowd was huge but this we expected."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": "august"
#   }
# }
# 809TH REVIEW
# {
#   "review_id": "403924982",
#   "coded_elements": [
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "ride breakdowns impact fastpass",
#       "text_excerpt": "even though most of the fast passes we had in our hands we could not use because rides would shut down"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "enjoyable shows",
#       "text_excerpt": "thank God for the shows."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 810TH REVIEW
# {
#   "review_id": "431202716",
#   "coded_elements": [
#     {
#       "touchpoint": "comparison",
#       "sentiment": "negative",
#       "code": "better service in Orlando",
#       "text_excerpt": "but the service and friendliness of staff is much better in Orlando"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "ride closures for refurbishment",
#       "text_excerpt": "There were a few rides such as Big Thunder Mountain closed for refurbishment"
#     },
#     {
#       "touchpoint": "timing",
#       "sentiment": "positive",
#       "code": "quieter weekday visits",
#       "text_excerpt": "if you can go on weekdays it is much quieter than on the weekend"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "fireworks viewing location tip",
#       "text_excerpt": "If you are watching Disney Dreams Fireworks you need to be facing the castle, so stand half way up main street."
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "avoiding post-fireworks rush",
#       "text_excerpt": "avoid the mad rush as everyone tries to leave at the one time"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "ice cream shop reasonable prices",
#       "text_excerpt": "There is a great ice cream shop on main street, quite reasonable pricewise too"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "restaurant good seating",
#       "text_excerpt": "lots of seating"
#     },
#     {
#       "touchpoint": "value",
#       "sentiment": "positive",
#       "code": "restaurants not too expensive",
#       "text_excerpt": "again not too bad pricewise"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "fastpass system benefit",
#       "text_excerpt": "If it's after 10.30 you can get another fastpass from an adjacent ride before you ride using your fastpass."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 811TH REVIEW
# {
#   "review_id": "175574269",
#   "coded_elements": [
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "amazing and interesting park",
#       "text_excerpt": "It was the most amazing and interesting park I have ever been to."
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "felt like a child",
#       "text_excerpt": "It made me feel like a child again."
#     },
#     {
#       "touchpoint": "cleanliness",
#       "sentiment": "positive",
#       "code": "clean park environment",
#       "text_excerpt": "It was clean"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "fun and exciting",
#       "text_excerpt": "fun and exciting"
#     },
#     {
#       "touchpoint": "timing",
#       "sentiment": "positive",
#       "code": "easy weekday line waiting",
#       "text_excerpt": "We went during the week and it was not difficult waiting in line."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "manageable ride queue",
#       "text_excerpt": "it was not difficult waiting in line"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": null,
#     "visit_timing": "week"
#   }
# }
# 812TH REVIEW
# {
#   "review_id": "483215863",
#   "coded_elements": [
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "negative",
#       "code": "crowded hot noisy",
#       "text_excerpt": "it's crowded, hot, and noisy"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "favorite classic attractions",
#       "text_excerpt": "Favorite attractions like Thunder Mountain Railroad, Star Tours, Splash Mountain (ride it during the heat of the day), and the timeless Pirates of the Carribean make this a wonderful experience."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "manage ride wait times",
#       "text_excerpt": "Use the Fast Pass to help manage your wait times at various attractions."
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "favorite eating spots",
#       "text_excerpt": "My favorite eating spots: Bengal Barbeque in Adventureland and Concina Cucamonga in Frontierland."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": "no",
#     "visit_timing": null
#   }
# }
# 813TH REVIEW
# {
#   "review_id": "420746020",
#   "coded_elements": [
#     {
#       "touchpoint": "timing",
#       "sentiment": "positive",
#       "code": "advantageous rainy day visit",
#       "text_excerpt": "it did mean that it was not crowded at all and we could get straight into any of the shows, rides and amusements that we wanted"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "magnificent fireworks display",
#       "text_excerpt": "The magnificent fireworks display at the end of the day was just the icing on the cake."
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "positive",
#       "code": "easy transport to venue",
#       "text_excerpt": "Transport to and from was easy"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "themed train carriages",
#       "text_excerpt": "I especially loved the Disneyland train carriages with their blue seat, and Mickey Mouse windows and handles."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 814TH REVIEW
# {
#   "review_id": "260905577",
#   "coded_elements": [
#     {
#       "touchpoint": "value",
#       "sentiment": "negative",
#       "code": "park visit overpriced",
#       "text_excerpt": "It's overpriced"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "park overcrowded",
#       "text_excerpt": "and overcrowded"
#     },
#     {
#       "touchpoint": "value",
#       "sentiment": "negative",
#       "code": "too many free tickets",
#       "text_excerpt": "There seems to be too many free tickets being handed out."
#     },
#     {
#       "touchpoint": "entry/admission",
#       "sentiment": "negative",
#       "code": "many unpaid guests",
#       "text_excerpt": "The park is full of people that don't seem to have paid for admission."
#     },
#     {
#       "touchpoint": "value",
#       "sentiment": "negative",
#       "code": "expensive hopper tickets",
#       "text_excerpt": "We paid hundreds of dollars for our hopper tickets."
#     },
#     {
#       "touchpoint": "cleanliness",
#       "sentiment": "negative",
#       "code": "garbage covered walkways",
#       "text_excerpt": "The walkways are covered in garbage."
#     },
#     {
#       "touchpoint": "facilities",
#       "sentiment": "negative",
#       "code": "filthy bathrooms",
#       "text_excerpt": "The bathrooms are filthy."
#     },
#     {
#       "touchpoint": "retail",
#       "sentiment": "negative",
#       "code": "cheap merchandise quality",
#       "text_excerpt": "The merchandise that is sold in the stores is all cheap made in China products."
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "poor food quality",
#       "text_excerpt": "Food is poor is Disneyland"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "good food Downtown Disney",
#       "text_excerpt": "but fairly good in Downtown Disney."
#     },
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "negative",
#       "code": "will not return",
#       "text_excerpt": "We won't be going to Disneyland again."
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "negative",
#       "code": "lost its charm",
#       "text_excerpt": "it's lost it's charm for us"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": "no",
#     "visit_timing": null
#   }
# }
# 815TH REVIEW
# {
#   "review_id": "321332464",
#   "coded_elements": [
#     {
#       "touchpoint": "timing",
#       "sentiment": "positive",
#       "code": "advantageous public holiday crowds",
#       "text_excerpt": "We lucked out and got there on a Public Holiday and the park was relatively crowd free!"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "minimal ride queue times",
#       "text_excerpt": "Was able to ride everything multiple times with no wait time over 10mins which is ridiculously good."
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "positive",
#       "code": "low general crowd density",
#       "text_excerpt": "the park was relatively crowd free!"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": "Public Holiday"
#   }
# }
# 816TH REVIEW
# {
#   "review_id": "156026094",
#   "coded_elements": [
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "excessive park crowding",
#       "text_excerpt": "Was very over crowded, in fact, it seemed to be more crowded than Christmas."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "long ride queue",
#       "text_excerpt": "The line ups for rides was as mush as 3 hours."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 817TH REVIEW
# {
#   "review_id": "159548447",
#   "coded_elements": [
#     {
#       "touchpoint": "characters",
#       "sentiment": "positive",
#       "code": "memorable princess character interactions",
#       "text_excerpt": "Princesses was my favorite"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "scary haunted house",
#       "text_excerpt": "the haunted house is scary"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 818TH REVIEW
# {
#   "review_id": "333383501",
#   "coded_elements": [
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "negative",
#       "code": "low on excitement",
#       "text_excerpt": "a little low on the excitement pole"
#     },
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "negative",
#       "code": "one visit was enough",
#       "text_excerpt": "No once was enough"
#     },
#     {
#       "touchpoint": "comparison",
#       "sentiment": "negative",
#       "code": "different than Disney World",
#       "text_excerpt": "very different atmosphere than Disney World Florida"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": "early November 2015"
#   }
# }
# 819TH REVIEW
# {
#   "review_id": "346834818",
#   "coded_elements": [
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "new rides and attractions",
#       "text_excerpt": "The presentations are quite new and so are the rides."
#     },
#     {
#       "touchpoint": "comparison",
#       "sentiment": "negative",
#       "code": "not same as other parks",
#       "text_excerpt": "It may seem like the same as that of other Disneyland's, well you will be in for a surprise of sorts."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "new presentations and shows",
#       "text_excerpt": "The presentations are quite new"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": "yes",
#     "visit_timing": null
#   }
# }
# 820TH REVIEW
# {
#   "review_id": "552249569",
#   "coded_elements": [
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "lots of ride options",
#       "text_excerpt": "lots of rides to go on"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "brilliant new year fireworks",
#       "text_excerpt": "the new year fireworks was brilliant"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": null,
#     "visit_timing": "new year"
#   }
# }
# 821TH REVIEW
# {
#   "review_id": "535154413",
#   "coded_elements": [
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "understanding fast pass important",
#       "text_excerpt": "you need to know how does it function with the fast pass, other wise, you could spend the hole journey and not doing half of the park"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "strategy maximize fast pass",
#       "text_excerpt": "Once you arrive go and grab a fast pass for 1 attraction and go for another attraction.Once you finish the attraction, you ll go direct to the fast pass at the time you have already choosed and do it, once finish, just do the same .. go for a fast pass one, get your ticket and then go quick to another attraction"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 822TH REVIEW
# {
#   "review_id": "248192557",
#   "coded_elements": [
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "difficult park navigation",
#       "text_excerpt": "It was so crowded that it was difficult to walk"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "excessive ride queue length",
#       "text_excerpt": "queues were super long"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "high general crowding level",
#       "text_excerpt": "It was so crowded"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": "holidays"
#   }
# }
# 823TH REVIEW
# {
#   "review_id": "125411788",
#   "coded_elements": [
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "enjoyable ride experience",
#       "text_excerpt": "I love the rides"
#     },
#     {
#       "touchpoint": "staff",
#       "sentiment": "positive",
#       "code": "honest and kind staff",
#       "text_excerpt": "people are honest and kind"
#     },
#     {
#       "touchpoint": "staff",
#       "sentiment": "positive",
#       "code": "item returned to lost",
#       "text_excerpt": "someone will give it to the Lost and Found Area"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 824TH REVIEW
# {
#   "review_id": "238249432",
#   "coded_elements": [
#     {
#       "touchpoint": "characters",
#       "sentiment": "negative",
#       "code": "lack of character appearances",
#       "text_excerpt": "But this time the only characters we saw were Mickey (in his normal place with a queue), Goofy (once) and Jack Skellington (once). Thats not much Disney for two parks in two full days"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "frequent ride malfunctions",
#       "text_excerpt": "Also disappointing was the frequent ride malfuntions."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "ride queue after breakdown",
#       "text_excerpt": "Day one headed straight for Indianna Jones   technical problems, so had to go elsewhere and join the back of other queues!"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "ride queue after breakdown",
#       "text_excerpt": "Day two headed straight for Rattatoui   technical problems! (As we were near the front of this queue we decided to stay put, as thought it would be quicker to wait for them to fix the ride than to join a 2 hour queue later in the day."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "ride closure inconvenience",
#       "text_excerpt": "Also on day 1 Pirates of the Caribbean was closed when we went and had to return the following day to ride it."
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "enjoyable parade experience",
#       "text_excerpt": "The parade in Disneyland Park was really good as always"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "enjoyable nighttime show",
#       "text_excerpt": "and we thoroughly enjoyed the nightime show on the castle. Definitely worth staying out for (or coming back for if you've popped out for dinner)."
#     },
#     {
#       "touchpoint": "comparison",
#       "sentiment": "negative",
#       "code": "ride closures Orlando comparison",
#       "text_excerpt": "**They don't seem to have these unscheduled ride closures in Orlando."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "mickey meet queue",
#       "text_excerpt": "Mickey (in his normal place with a queue)"
#     },
#     {
#       "touchpoint": "timing",
#       "sentiment": "negative",
#       "code": "hour ride queue delay",
#       "text_excerpt": "Ride eventually opened about an hour after park opening   frustrating!"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": "no",
#     "visit_timing": "half term"
#   }
# }
# 825TH REVIEW
# {
#   "review_id": "184219850",
#   "coded_elements": [
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "reasonable prices and delicious",
#       "text_excerpt": "My family agreed the food was fairly reasonably priced and was really delicious."
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "good food variety offered",
#       "text_excerpt": "A good variety of foods were on offer and were really delicious!"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "advertised queue times accurate",
#       "text_excerpt": "The queues were fairly long but the advertised times were true"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "beautifully decorated queues",
#       "text_excerpt": "the lines were beautifully decorated"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "positive",
#       "code": "manageable summer holiday crowds",
#       "text_excerpt": "never felt like it was crowded"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "acceptable summer holiday wait",
#       "text_excerpt": "the wait times were too long"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "vibrant colors amazing scenery",
#       "text_excerpt": "The place was beautifully presented with vibrant colours and amazing scenery!"
#     },
#     {
#       "touchpoint": "staff",
#       "sentiment": "positive",
#       "code": "polite and helpful staff",
#       "text_excerpt": "We found the staff to be very polite and helpful when walking around"
#     },
#     {
#       "touchpoint": "staff",
#       "sentiment": "positive",
#       "code": "friendly cast member interaction",
#       "text_excerpt": "a lot of cast members waved with a cheery bonjour and commented on my pin badges!"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "magical parades night spectacular",
#       "text_excerpt": "The parades were magical and the night time spectacular was amazing!"
#     },
#     {
#       "touchpoint": "characters",
#       "sentiment": "positive",
#       "code": "fun character interactions",
#       "text_excerpt": "We found lots of characters walking around who were lots of good fun dancing and playing with the children!"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "reasonable riverboat queue time",
#       "text_excerpt": "the queue wasnt too long"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "peaceful relaxing riverboat cruise",
#       "text_excerpt": "on the lower deck it was so peaceful and relaxing"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "calming music during cruise",
#       "text_excerpt": "Calming music was played as you slowly drifted around, even the ducks swam along side the boat!"
#     },
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "positive",
#       "code": "truly magical experience",
#       "text_excerpt": "Overall, a truly magical experience!"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": "no",
#     "visit_timing": "summer holidays"
#   }
# }
# 826TH REVIEW
# {
#   "review_id": "227403003",
#   "coded_elements": [
#     {
#       "touchpoint": "staff",
#       "sentiment": "positive",
#       "code": "knowledgeable ART driver",
#       "text_excerpt": "the knowledge of the ART driver was amazing"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "positive",
#       "code": "convenient transportation access",
#       "text_excerpt": "Super convenient"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 827TH REVIEW
# {
#   "review_id": "339563423",
#   "coded_elements": [
#     {
#       "touchpoint": "pre-visit",
#       "sentiment": "positive",
#       "code": "efficient online ticket purchase",
#       "text_excerpt": "Bought my online tickets online as my parents were HK residents and got a little discount."
#     },
#     {
#       "touchpoint": "entry/admission",
#       "sentiment": "positive",
#       "code": "helpful guest relations refund",
#       "text_excerpt": "Got the wrong tickets but  guest relations  refunded me when I got there so was very happy."
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "challenging crowd management",
#       "text_excerpt": "Lost my 3 yo 3 times that day because there were a lot of people but luckily found!"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "avoided food queue",
#       "text_excerpt": "Food was yummy although we ate at 2pm so skipped the crowds."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": null,
#     "visit_timing": "summer holidays"
#   }
# }
# 828TH REVIEW
# {
#   "review_id": "490487069",
#   "coded_elements": [
#     {
#       "touchpoint": "cleanliness",
#       "sentiment": "positive",
#       "code": "park well maintained",
#       "text_excerpt": "Everything is so well maintained"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "park well run",
#       "text_excerpt": "and well run"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "unhealthy food options",
#       "text_excerpt": "the unhealthy food"
#     },
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "positive",
#       "code": "positive overall reflection",
#       "text_excerpt": "loved this trip even more"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": "no",
#     "visit_timing": null
#   }
# }
# 829TH REVIEW
# {
#   "review_id": "340630939",
#   "coded_elements": [
#     {
#       "touchpoint": "pre-visit",
#       "sentiment": "positive",
#       "code": "excellent train transport",
#       "text_excerpt": "Transport was excellent I can't really fault that."
#     },
#     {
#       "touchpoint": "entry/admission",
#       "sentiment": "negative",
#       "code": "unhelpful hotel location assistance",
#       "text_excerpt": "very little help was available for locating our hotel"
#     },
#     {
#       "touchpoint": "entry/admission",
#       "sentiment": "negative",
#       "code": "difficult walk with luggage",
#       "text_excerpt": "We ended up walking through a security checkpoint and part of the park to get to the hotel with a long walk. Quite difficult with luggage and two small children."
#     },
#     {
#       "touchpoint": "facilities",
#       "sentiment": "positive",
#       "code": "comfortable hotel room",
#       "text_excerpt": "These were quite nicely furbished, comfortable for our three night stay. Comfortable bed with nice pillows."
#     },
#     {
#       "touchpoint": "facilities",
#       "sentiment": "negative",
#       "code": "no in-room coffee",
#       "text_excerpt": "No tea coffee making facility though!"
#     },
#     {
#       "touchpoint": "facilities",
#       "sentiment": "positive",
#       "code": "convenient multi-plug sockets",
#       "text_excerpt": "multi function plug sockets in the dressing table which were a good idea"
#     },
#     {
#       "touchpoint": "facilities",
#       "sentiment": "negative",
#       "code": "obstructed hotel view",
#       "text_excerpt": "there was scaffolding outside our window, these had plastic coverings so no view over the lake or balcony access."
#     },
#     {
#       "touchpoint": "facilities",
#       "sentiment": "negative",
#       "code": "overheated hotel room",
#       "text_excerpt": "The rooms were like ovens and my son was unable to open any windows. Thankfully our windows opened."
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "adequate basic breakfast",
#       "text_excerpt": "Breakfast was included, a fairly basic continental style selection but adequate."
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "long walk from hotel",
#       "text_excerpt": "The park itself is quite a walk from the hotel"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "positive",
#       "code": "avoiding shuttle bus scrum",
#       "text_excerpt": "we chose to walk to save the scrum of getting on a bus."
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "negative",
#       "code": "unfriendly atmosphere",
#       "text_excerpt": "It was unfriendly, not the same atmosphere as Florida."
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "extreme park crowding",
#       "text_excerpt": "The place was rammed with people."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "long queues for rides",
#       "text_excerpt": "Queuing was long for everything with some very short rides at the end of it."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "long ride queue wait time",
#       "text_excerpt": "if you had the patience to q for an hour and a half or more."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "difficult to entertain children",
#       "text_excerpt": "considering the amount of queuing and the short rides it was quite difficult to keep them entertained."
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "good parade performance",
#       "text_excerpt": "There were parades that took place and were quite good"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "effective light show fireworks",
#       "text_excerpt": "in the evening a light show and fireworks over the Castle were very effective."
#     },
#     {
#       "touchpoint": "characters",
#       "sentiment": "negative",
#       "code": "limited character presence",
#       "text_excerpt": "lack of Disney characters around. They made appearances in defined areas where you could q to have a photo with them but none wandered around."
#     },
#     {
#       "touchpoint": "characters",
#       "sentiment": "negative",
#       "code": "massive queue for princesses",
#       "text_excerpt": "a massive q had to be passed through to get a photo with one."
#     },
#     {
#       "touchpoint": "comparison",
#       "sentiment": "negative",
#       "code": "lacked disney magic",
#       "text_excerpt": "I felt that the place lacked the  Disney Magic  that I had felt in Florida."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": null,
#     "visit_timing": "New Year"
#   }
# }
# 830TH REVIEW
# {
#   "review_id": "279124019",
#   "coded_elements": [
#     {
#       "touchpoint": "timing",
#       "sentiment": "positive",
#       "code": "advantageous midweek visit",
#       "text_excerpt": "We visited mid week"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "sufficient shade and coolness",
#       "text_excerpt": "enough shade and cool places so we didn't find the heat a real problem"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "positive",
#       "code": "manageable general crowding",
#       "text_excerpt": "nowhere near crazy packed"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "short ride queue",
#       "text_excerpt": "This made most rides only a short wait ( 20 min)"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "multiple ride experiences",
#       "text_excerpt": "managed to repeat many rides"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "long Autopia queue",
#       "text_excerpt": "Autopia queues get very long early, move slowly, and have a lot of families."
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "limited restaurant availability",
#       "text_excerpt": "Quite a few restaurants were closed (off peak?)"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "ordinary food choices",
#       "text_excerpt": "we found the eating choices a bit ordinary"
#     },
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "negative",
#       "code": "early departure choice",
#       "text_excerpt": "decision to leave early before the fireworks."
#     },
#     {
#       "touchpoint": "pre-visit",
#       "sentiment": "positive",
#       "code": "easy metro connections",
#       "text_excerpt": "The metro connections are easy although it will still take a while to get there."
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "themed transport mood setter",
#       "text_excerpt": "The last metro ride is purely Disney and it helps to put you in the mood as it's themed."
#     },
#     {
#       "touchpoint": "value",
#       "sentiment": "positive",
#       "code": "ticket price good value",
#       "text_excerpt": "I thought the ticket price was good value given all the included rides and live entertainment."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": "mid week"
#   }
# }
# 831TH REVIEW
# {
#   "review_id": "286998699",
#   "coded_elements": [
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "positive",
#       "code": "recommend visit disneyland",
#       "text_excerpt": "a visit to the Hong Kong Disneyland is a must do"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "excellent non-stop entertainment",
#       "text_excerpt": "The entertainment is excellent and non stop"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "great 3d cinema experience",
#       "text_excerpt": "The 3 D cinena is really great"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "immersive sensory experience",
#       "text_excerpt": "You can feel the wind and rain as well as the aromas"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "family friendly entertainment",
#       "text_excerpt": "Very good entertainment for the entire family young and old"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 832TH REVIEW
# {
#   "review_id": "213562925",
#   "coded_elements": [
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "great disneyland food outlets",
#       "text_excerpt": "all food outlets are great  at disneyland"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "worth food queue wait",
#       "text_excerpt": "just join the queue its worth the wait"
#     },
#     {
#       "touchpoint": "timing",
#       "sentiment": "positive",
#       "code": "multiple-day visit recommended",
#       "text_excerpt": "try them all over a 3 day day its good fun"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 833TH REVIEW
# {
#   "review_id": "469165056",
#   "coded_elements": [
#     {
#       "touchpoint": "cleanliness",
#       "sentiment": "positive",
#       "code": "immaculate park environment",
#       "text_excerpt": "The parks are immaculate"
#     },
#     {
#       "touchpoint": "atmosphere",
# ...
#       "sentiment": "positive",
#       "code": "incredible Mystic Point",
#       "text_excerpt": "Mystic Point would have been incredible"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "Mystic Point too small",
#       "text_excerpt": "had it been much bigger"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "solo",
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 991TH REVIEW
# {
#   "review_id": "249059654",
#   "coded_elements": [
#     {
#       "touchpoint": "pre-visit",
#       "sentiment": "negative",
#       "code": "long ticket booth queue",
#       "text_excerpt": "we had to queue for over an hour at the ticket booth to exchange our voucher for entry tickets"
#     },
#     {
#       "touchpoint": "entry/admission",
#       "sentiment": "negative",
#       "code": "park access denied",
#       "text_excerpt": "Disneyland was FULL and that we were unable to enter the park until after 5.30pm!!"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "using FastPass system",
#       "text_excerpt": "We soon got the hang of using the FastPass system essential if you don't wan't to spend most of your day standing in a queue."
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "crowded park navigation issues",
#       "text_excerpt": "Disneyland was still crowded after 5.30pm and it was difficult to get our bearings in the dark"
#     },
#     {
#       "touchpoint": "entry/admission",
#       "sentiment": "positive",
#       "code": "early entry advantage",
#       "text_excerpt": "we (along with quite a few other people) could get into Disneyland at 7am   an hour before it opened to the public"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "minimal ride queue times",
#       "text_excerpt": "we went on the popular rides like Space Mountain (twice) and Star Tours without having to queue"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "excessive stroller crowding",
#       "text_excerpt": "I have never seen so many strollers in one place at one time!"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "extreme FastPass wait",
#       "text_excerpt": "we managed to get a FastPass for Radiator Springs at 11am that told us to return at our allocated time slot which was 10 11pm that night   11 hours later!"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "spectacular fireworks display",
#       "text_excerpt": "The fireworks over Sleeping Beauty's Castle were spectacular (even more so than usual)"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "negative",
#       "code": "excessive parade viewing crowding",
#       "text_excerpt": "Main Street was crammed full of thousands and thousands of bodies gazing skyward"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "festive holiday decorations",
#       "text_excerpt": "It was magical to see Disneyland all decorated for the holidays (including fake falling snow)"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "wonderful holiday theming",
#       "text_excerpt": "It's A Small World was wonderful with it's Christmas theming"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "negative",
#       "code": "crowds dull magic",
#       "text_excerpt": "the crowds and long wait times did manage to dull the magic a little"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": null,
#     "visit_timing": "Christmas holidays"
#   }
# }
# 992TH REVIEW
# {
#   "review_id": "159423773",
#   "coded_elements": [
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "positive",
#       "code": "memorable magical experience",
#       "text_excerpt": "very magical."
#     },
#     {
#       "touchpoint": "general",
#       "sentiment": "positive",
#       "code": "overall positive experience",
#       "text_excerpt": "Great day out"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": "yes",
#     "visit_timing": null
#   }
# }
# 993TH REVIEW
# {
#   "review_id": "131483166",
#   "coded_elements": [
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "excellent and outstanding rides",
#       "text_excerpt": "Disneyland Paris has excellent and outstanding rides"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "outstanding shows and parades",
#       "text_excerpt": "shows and parades"
#     },
#     {
#       "touchpoint": "comparison",
#       "sentiment": "positive",
#       "code": "good as Disney World",
#       "text_excerpt": "is as good as Disney World in Florida"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "expensive food and drink",
#       "text_excerpt": "the food and drink is very expensive"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "high cost of coke",
#       "text_excerpt": "It is 3 euros for a bottle of coke"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "expensive buffet restaurants",
#       "text_excerpt": "30 40 euros each in a buffet restaurant"
#     },
#     {
#       "touchpoint": "value",
#       "sentiment": "negative",
#       "code": "expensive food costs",
#       "text_excerpt": "food and drink is very expensive"
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "positive",
#       "code": "park is very accessible",
#       "text_excerpt": "the park is very accessible"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "truly magical place",
#       "text_excerpt": "Disneyland Park is a truly magical place"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "families",
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 994TH REVIEW
# {
#   "review_id": "283963913",
#   "coded_elements": [
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "beautiful anniversary decorations",
#       "text_excerpt": "all of the 60th decorations were beautiful"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "incredible light parade",
#       "text_excerpt": "The light parade was incredible"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": null
#   }
# }
# 995TH REVIEW
# {
#   "review_id": "362480264",
#   "coded_elements": [
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "portion of park closed",
#       "text_excerpt": "large amount of Park was shut"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "limited open snack options",
#       "text_excerpt": "lack of places to get snacks that were actually open. So lack of coffee etc."
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "restaurants limited to food",
#       "text_excerpt": "restaurants would only serve food"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "princess dinner worth price",
#       "text_excerpt": "We did the dinner with Princesses which was worth the money."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": null,
#     "visit_timing": "April"
#   }
# }
# 996TH REVIEW
# {
#   "review_id": "330029779",
#   "coded_elements": [
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "positive",
#       "code": "cannot fault the visit",
#       "text_excerpt": "Cannot fault the visit."
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "magic totally alive",
#       "text_excerpt": "The magic totally alive"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "lots of great rides",
#       "text_excerpt": "lots of great rides"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "stunning christmas decorations",
#       "text_excerpt": "Christmas decorations were stunning"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "love fireworks spectacular",
#       "text_excerpt": "Love the fireworks spectacular"
#     }
#   ],
#   "demographic_info": {
#     "travel_party": null,
#     "first_visit": null,
#     "visit_timing": "christmas"
#   }
# }
# 997TH REVIEW
# {
#   "review_id": "204781099",
#   "coded_elements": [
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "fantastic Dreams show",
#       "text_excerpt": "the shows were fantastic especially the Dreams show at 10pm definitely worth keeping the kids up one night to see it"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "stunt cars show loved",
#       "text_excerpt": "Also the stunt cars show which the 3 boys loved"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "fab springtime parade",
#       "text_excerpt": "the day springtime parade with all the characters were fab"
#     },
#     {
#       "touchpoint": "pre-visit",
#       "sentiment": "positive",
#       "code": "cheaper online tickets",
#       "text_excerpt": "I got tickets off of Ticketnet.fr as they were cheaper and you can print them off yourself"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "enjoyable Buffalo Bills show",
#       "text_excerpt": "Would definitely recommend booking Buffalo bills Wild West show, we all really enjoyed this"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "food included pleasant surprise",
#       "text_excerpt": "You had food included which we were pleasantly surprised with"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "free flowing beer adults",
#       "text_excerpt": "& adults got free flowing beer"
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "lots crowd participation",
#       "text_excerpt": "& there is lots of crowd participation"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "expensive park food",
#       "text_excerpt": "Obviously eating out in the park is quite expensive"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "positive",
#       "code": "reasonable McDonald's prices",
#       "text_excerpt": "but McDonald's seemed pretty reasonable"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "burger limited menu",
#       "text_excerpt": "although most places just seem to do burgers"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "long Pirates ride queue",
#       "text_excerpt": "The downside was the queues for rides, myself & sister in law queued with 3 boys for 1 hour to get on pirates of the Caribbean"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "ride broke down",
#       "text_excerpt": "and when we were nearly at the front it broke down so we had to leave"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "long Peter Pan queue",
#       "text_excerpt": "we also queued for 1hr 15mins for Peter Pan ride which lasted about 2minutes"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "Crush's Coaster long queue",
#       "text_excerpt": "We didn't manage to get on Crush's ride as queue said 90 mins"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "rides broke down annoying",
#       "text_excerpt": "Some rides also broke down which was slightly annoying"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "used fast pass",
#       "text_excerpt": "we used the fast pass as much as possible but these are mainly for the bigger rides"
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "negative",
#       "code": "disappointing tram tour",
#       "text_excerpt": "We were disappointed with the tram tour wasn't much of it really apart from 2 dramatic areas but I was expecting abit more"
#     },
#     {
#       "touchpoint": "cleanliness",
#       "sentiment": "positive",
#       "code": "park very clean",
#       "text_excerpt": "We found the park itself very clean"
#     },
#     {
#       "touchpoint": "atmosphere",
#       "sentiment": "positive",
#       "code": "lovely park setting",
#       "text_excerpt": "and a lovely setting especially the castle itself which is stunning"
#     },
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "negative",
#       "code": "one off place",
#       "text_excerpt": "However I think it's a one off place now we've done it I don't think we'll be going back for a while."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": null,
#     "visit_timing": "Friday 2nd Monday 5th"
#   }
# }
# 998TH REVIEW
# {
#   "review_id": "558932183",
#   "coded_elements": [
#     {
#       "touchpoint": "pre-visit",
#       "sentiment": "positive",
#       "code": "convenient hotel shuttle service",
#       "text_excerpt": "our hotel provided shuttle to Disney land which got us there in just 15     20 mins"
#     },
#     {
#       "touchpoint": "entry/admission",
#       "sentiment": "positive",
#       "code": "welcoming fountain display",
#       "text_excerpt": "The fountain of Mickey on a giant whale was quite welcoming."
#     },
#     {
#       "touchpoint": "characters",
#       "sentiment": "positive",
#       "code": "interactive character experience",
#       "text_excerpt": "There was a live Mickey and Mini interaction when we entered and clicking pics with them which gave a kick start to the day."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "enjoyable ride experience",
#       "text_excerpt": "The rest of the rides were nice and we enjoyed a lot."
#     },
#     {
#       "touchpoint": "attractions",
#       "sentiment": "positive",
#       "code": "short ride queue times",
#       "text_excerpt": "being Sunday the wait time was not more than 15     20 mins."
#     },
#     {
#       "touchpoint": "navigation",
#       "sentiment": "positive",
#       "code": "effective use of park maps",
#       "text_excerpt": "would suggest to make proper use of maps and the timings mentioned on it for the rides so that you don   t miss any"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "limited ethnic food options",
#       "text_excerpt": "being an Indian we would prefer Asian or Indian meal but we couldn   t found any options other than European food"
#     },
#     {
#       "touchpoint": "food/beverage",
#       "sentiment": "negative",
#       "code": "inaccurate restaurant information",
#       "text_excerpt": "Also, the Indian restaurants that were shown on map were all shut and there was no update regarding the same coz it was far and we had to search walking which was very time consuming."
#     },
#     {
#       "touchpoint": "entertainment",
#       "sentiment": "positive",
#       "code": "memorable fireworks show",
#       "text_excerpt": "the very famous Disney Fireworks (09:00 pm) a not to be missed stuff, is a treat to the eyes and it makes you forget the entire day   s tiredness"
#     },
#     {
#       "touchpoint": "post-visit",
#       "sentiment": "positive",
#       "code": "positive overall experience",
#       "text_excerpt": "Over all experience was wonderful and would really suggest to visit once in your life."
#     }
#   ],
#   "demographic_info": {
#     "travel_party": "family",
#     "first_visit": "yes",
#     "visit_timing": "Sunday"
#   }
# }
# 999TH REVIEW

# %%
import json
import pandas as pd

def load_json_to_dataframe(returned_responses):
    # Initialize empty list to collect all review data
    all_reviews_data = []
    
    # If a single string is passed, convert to list
    if isinstance(returned_responses, str):
        returned_responses = [returned_responses]
    
    # Process each JSON string
    for returned_response in returned_responses:
        # Parse the JSON string
        data = json.loads(returned_response)
        
        # Validate with Pydantic using model_validate (v2 method)
        if isinstance(data, list):
            # If it's a list of reviews
            validated_data = [ReviewAnalysis.model_validate(item) for item in data]
        else:
            # If it's a single review
            validated_data = [ReviewAnalysis.model_validate(data)]
            
        # Normalize the data for a DataFrame
        for review in validated_data:
            # For each coded element in a review, create a row
            for element in review.coded_elements:
                row = {
                    'review_id': review.review_id,
                    'touchpoint': element.touchpoint,
                    'sentiment': element.sentiment,
                    'code': element.code,
                    'text_excerpt': element.text_excerpt,
                    'travel_party': review.demographic_info.travel_party,
                    'first_visit': review.demographic_info.first_visit,
                    'visit_timing': review.demographic_info.visit_timing
                }
                all_reviews_data.append(row)
    
    # Create DataFrame from all collected data
    if all_reviews_data:
        df = pd.DataFrame(all_reviews_data)
        return df
    else:
        # Return empty DataFrame if no valid data
        return pd.DataFrame()

# %%
n800to1000 = load_json_to_dataframe(llm_output)

# %%
n800to1000.to_csv("data/n800to1000.csv", index=False)
